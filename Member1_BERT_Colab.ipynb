# %% [markdown]
# # Member 1 BERT Training — Google Colab
# Run this notebook from the extracted project folder. Use genuine outputs only and understand every step.

# %% [markdown]
# ## 1. Upload the project ZIP
# Run the next cell and choose `NLP_Group_07_Member1_Starter.zip`.

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !unzip -q NLP_Group_07_Member1_Starter.zip -d /content/
# %cd /content/NLP_Group_07_Member1_Starter

# %% [markdown]
# ## 2. Install dependencies

# %%
# !pip install -q -r requirements_baseline.txt -r requirements_bert.txt

# %% [markdown]
# ## 3. Confirm the runtime
# A CUDA device indicates that a GPU is available.

# %%
import torch
print('PyTorch:', torch.__version__)
print('CUDA available:', torch.cuda.is_available())
print('Device:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU')

# %% [markdown]
# ## 4. Inspect the real datasets

# %%
# !python -m src.member1.inspect_data

# %% [markdown]
# ## 5. Quick progress run
# This one-epoch reduced run is for verifying that the pipeline works. Label it as a progress experiment.

# %%
# !python -m src.member1.train_bert --epochs 1 --batch-size 8 --max-length 128 --max-records 250

# %% [markdown]
# ## 6. Full planned run
# Run after the quick test succeeds. Adjust batch size if GPU memory is limited.

# %%
# !python -m src.member1.train_bert --epochs 2 --batch-size 8 --max-length 256

# %% [markdown]
# ## 7. Download genuine outputs

# %%
# !zip -qr member1_bert_outputs.zip models/member1/bert_job_classifier reports/member1/bert_training_metrics.json
files.download('member1_bert_outputs.zip')
